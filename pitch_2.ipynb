# %%
import pandas as pd

# %%
df = pd.read_csv("rawdata/50_state_student_loan.csv")

# %%
df.head()
# Out:
#    fips  state_name state  Share with Student Loan Debt, All  \
# 0     1     Alabama    AL                           0.151480
# 1     2      Alaska    AK                           0.132789
# 2     4     Arizona    AZ                           0.149399
# 3     5    Arkansas    AR                           0.156112
# 4     6  California    CA                           0.119939
#
#    Share with Student Loan Debt, Communities of Color  \
# 0                                           0.188413
# 1                                           0.095364
# 2                                           0.138949
# 3                                           0.208239
# 4                                           0.119639
#
#    Share with Student Loan Debt, Majority White Communities  \
# 0                                           0.139286
# 1                                           0.127538
# 2                                           0.145217
# ...

# %%
df.drop(columns=['Share with Student Loan Debt, All', 'Share with Student Loan Debt, Communities of Color', 'Share with Student Loan Debt, Majority White Communities'])
# Out:
#     fips            state_name state  Median Student Loan Debt, All  \
# 0      1               Alabama    AL                          19874
# 1      2                Alaska    AK                          18278
# 2      4               Arizona    AZ                          18269
# 3      5              Arkansas    AR                          18226
# 4      6            California    CA                          17973
# 5      8              Colorado    CO                          20555
# 6      9           Connecticut    CT                          20169
# 7     10              Delaware    DE                          21178
# 8     11  District of Columbia    DC                          28399
# 9     12               Florida    FL                          20198
# 10    13               Georgia    GA                          22748
# 11    15                Hawaii    HI                          18824
# 12    16                 Idaho    ID                          18378
# ...

# %%
df.drop(columns=['Share of Student Loan Holders with Student Debt in Collections, All', 'Share of Student Loan Holders with Student Debt in Collections, Communities of C', 'Share of Student Loan Holders with Student Debt in Collections, Majority White C'])
# Out:
#     fips            state_name state  Share with Student Loan Debt, All  \
# 0      1               Alabama    AL                           0.151480
# 1      2                Alaska    AK                           0.132789
# 2      4               Arizona    AZ                           0.149399
# 3      5              Arkansas    AR                           0.156112
# 4      6            California    CA                           0.119939
# 5      8              Colorado    CO                           0.177005
# 6      9           Connecticut    CT                           0.180313
# 7     10              Delaware    DE                           0.157846
# 8     11  District of Columbia    DC                           0.214179
# 9     12               Florida    FL                           0.136064
# 10    13               Georgia    GA                           0.184806
# 11    15                Hawaii    HI                           0.113980
# ...

# %%
df.drop(columns=['Share with Student Loan Debt, All', 'Share with Student Loan Debt, Communities of Color', 'Share with Student Loan Debt, Majority White Communities', 'Share of Student Loan Holders with Student Debt in Collections, All', 'Share of Student Loan Holders with Student Debt in Collections, Communities of C', 'Share of Student Loan Holders with Student Debt in Collections, Majority White C', "Share without a Bachelor's degree, All", "Share without a Bachelor's degree, Communities of Color", "Share without a Bachelor's degree, Majority White Communities"])
# Out:
#     fips            state_name state  Median Student Loan Debt, All  \
# 0      1               Alabama    AL                          19874
# 1      2                Alaska    AK                          18278
# 2      4               Arizona    AZ                          18269
# 3      5              Arkansas    AR                          18226
# 4      6            California    CA                          17973
# 5      8              Colorado    CO                          20555
# 6      9           Connecticut    CT                          20169
# 7     10              Delaware    DE                          21178
# 8     11  District of Columbia    DC                          28399
# 9     12               Florida    FL                          20198
# 10    13               Georgia    GA                          22748
# 11    15                Hawaii    HI                          18824
# 12    16                 Idaho    ID                          18378
# ...

# %%
loandollar_df = df.drop(columns=['Share with Student Loan Debt, All', 'Share with Student Loan Debt, Communities of Color', 'Share with Student Loan Debt, Majority White Communities', 'Share of Student Loan Holders with Student Debt in Collections, All', 'Share of Student Loan Holders with Student Debt in Collections, Communities of C', 'Share of Student Loan Holders with Student Debt in Collections, Majority White C', "Share without a Bachelor's degree, All", "Share without a Bachelor's degree, Communities of Color", "Share without a Bachelor's degree, Majority White Communities"])

# %%
loandollar_df
# Out:
#     fips            state_name state  Median Student Loan Debt, All  \
# 0      1               Alabama    AL                          19874
# 1      2                Alaska    AK                          18278
# 2      4               Arizona    AZ                          18269
# 3      5              Arkansas    AR                          18226
# 4      6            California    CA                          17973
# 5      8              Colorado    CO                          20555
# 6      9           Connecticut    CT                          20169
# 7     10              Delaware    DE                          21178
# 8     11  District of Columbia    DC                          28399
# 9     12               Florida    FL                          20198
# 10    13               Georgia    GA                          22748
# 11    15                Hawaii    HI                          18824
# 12    16                 Idaho    ID                          18378
# ...
